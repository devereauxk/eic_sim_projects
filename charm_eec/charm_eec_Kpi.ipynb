# %% [markdown]
# ## Figures for charm jet energy-energy correlator
#
# Data for each figure is read from csv files in my github which you can access with these urls defined below. These urls either have a histogram or graph format. The histogram files have the following format:
#
#      bincenter, binwidth, line #1 central value, line #1 error, line #2 central value, line #2 error, ...
#
# Graph csv files have the format:
#
#      x-value, y-value

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
np.set_printoptions(threshold=sys.maxsize)

# %%
pt_lo = [5, 10, 20]
pt_hi = [10, 20, 30]
eta_lo = [-3.5, -1, 1]
eta_hi = [-1, 1, 3.5]

colors = ["g", "b", "m"]
light_colors = ["lightgreen", "lightblue", "plum"]

# figures
pythia8_inclusive = "./analysis/ep_18_275_Kpi_pow1_inclusive/"
pythia8_D0injet = "./analysis/ep_18_275_Kpi_pow1_D0injet/"

# %%
# self-normalized charm jet eec

# inclusive in jet

inclusive_eec = []
inclusive_eec_err = []
for ieta in range(len(eta_lo)):
  data = np.loadtxt(pythia8_inclusive + "eec_overlay_"+str(ieta)+".csv", delimiter=",", dtype=float)
  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)
  inclusive_eec.append([pt0, pt1, pt2])
  inclusive_eec_err.append([pt0_err, pt1_err, pt2_err])
  bin_lo = np.array(bincenter) - 0.5*np.array(binwidth)
  bin_hi = np.array(bincenter) + 0.5*np.array(binwidth)

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("inclusive EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("self-normalized EEC")
  plt.xscale('log')
  plt.yscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(1E-4, 3E-1)
  for ipt in range(len(pt_lo)):
    plt.step(bincenter, inclusive_eec[ieta][ipt], where='mid', color=colors[ipt], label=str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, inclusive_eec[ieta][ipt], yerr=inclusive_eec_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
  plt.legend(loc='upper left')
  plt.show()

# D0 in jet
D0injet_eec = []
D0injet_eec_err = []
for ieta in range(len(eta_lo)):
  data = np.loadtxt(pythia8_D0injet + "eec_overlay_"+str(ieta)+".csv", delimiter=",", dtype=float)
  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)
  D0injet_eec.append([pt0, pt1, pt2])
  D0injet_eec_err.append([pt0_err, pt1_err, pt2_err])

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("D0 in jet, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("self-normalized EEC")
  plt.xscale('log')
  plt.yscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(1E-4, 3E-1)
  for ipt in range(len(pt_lo)):
    plt.step(bincenter, D0injet_eec[ieta][ipt], where='mid', color=colors[ipt], label=str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, D0injet_eec[ieta][ipt], yerr=D0injet_eec_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
  plt.legend(loc='upper left')
  plt.show()

# %%
# charm jet EEC relative-normalized to inclusive
rl_norm_lo = 1E-4
rl_norm_hi = 0.3


def hist_integral(bincenter, binwidth, y, a=None, b=None):
  integral = 0

  assert len(bincenter) == len(binwidth) and len(bincenter) == len(y)

  if a == None:
    a = bincenter[0] - 2*binwidth[0]
  if b == None:
    b = bincenter[len(bincenter)-1] + 2*binwidth[len(bincenter)-1]

  for ibin in range(len(bincenter)):
    if bincenter[ibin] >= a and bincenter[ibin] <= b:
      integral += binwidth[ibin] * y[ibin]

  return integral


# D0 in jet
D0injet_eec_relnorm = [None]
D0injet_eec_relnorm_err = [None]
for ieta in range(1,len(eta_lo)):
  this_eta = []
  this_eta_err = []
  for ipt in range(len(D0injet_eec)):
    relative_normalization = hist_integral(bincenter, binwidth, inclusive_eec[ieta][ipt], rl_norm_lo, rl_norm_hi) / hist_integral(bincenter, binwidth, D0injet_eec[ieta][ipt], rl_norm_lo, rl_norm_hi)
    this_eta.append(D0injet_eec[ieta][ipt] * relative_normalization)
    this_eta_err.append(D0injet_eec_err[ieta][ipt] * relative_normalization)
  D0injet_eec_relnorm.append(this_eta)
  D0injet_eec_relnorm_err.append(this_eta_err)

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("D0 in jet, relative-normalized to inclusive, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("relative-normalized EEC")
  plt.xscale('log')
  plt.yscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(1E-4, 3E-1)
  for ipt in range(len(pt_lo)):
    plt.step(bincenter, inclusive_eec[ieta][ipt], where='mid', color=colors[ipt], label="inclusive " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, inclusive_eec[ieta][ipt], yerr=inclusive_eec_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
  for ipt in range(len(pt_lo)):
    plt.step(bincenter, D0injet_eec_relnorm[ieta][ipt], where='mid', color=light_colors[ipt], label="charm jet " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, D0injet_eec_relnorm[ieta][ipt], yerr=D0injet_eec_relnorm_err[ieta][ipt], capsize=2, fmt='.', color=light_colors[ipt])
  plt.legend(loc='upper left')
  plt.show()

# D0 in pair
"""
D0inpair_eec_relnorm = [None]
D0inpair_eec_relnorm_err = [None]
for ieta in range(1,len(eta_lo)):
  this_eta = []
  this_eta_err = []
  for ipt in range(len(D0injet_eec)):
    relative_normalization = hist_integral(bincenter, binwidth, inclusive_eec[ieta][ipt], rl_norm_lo, rl_norm_hi) / hist_integral(bincenter, binwidth, D0inpair_eec[ieta][ipt], rl_norm_lo, rl_norm_hi)
    this_eta.append(D0inpair_eec[ieta][ipt] * relative_normalization)
    this_eta_err.append(D0inpair_eec_err[ieta][ipt] * relative_normalization)
  D0inpair_eec_relnorm.append(this_eta)
  D0inpair_eec_relnorm_err.append(this_eta_err)

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("D0 in pair, relative-normalized to inclusive, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("relative-normalized EEC")
  plt.xscale('log')
  plt.yscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(1E-4, 3E-1)
  for ipt in range(len(pt_lo)):
    plt.step(bincenter, inclusive_eec[ieta][ipt], where='mid', color=colors[ipt], label="inclusive " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, inclusive_eec[ieta][ipt], yerr=inclusive_eec_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
  for ipt in range(len(pt_lo)):
    plt.step(bincenter, D0inpair_eec_relnorm[ieta][ipt], where='mid', color=light_colors[ipt], label="charm jet " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, D0inpair_eec_relnorm[ieta][ipt], yerr=D0inpair_eec_relnorm_err[ieta][ipt], capsize=2, fmt='.', color=light_colors[ipt])
  plt.legend(loc='upper left')
  plt.show()
  """
# Out:
# '\nD0inpair_eec_relnorm = [None]\nD0inpair_eec_relnorm_err = [None]\nfor ieta in range(1,len(eta_lo)):\n  this_eta = []\n  this_eta_err = []\n  for ipt in range(len(D0injet_eec)):\n    relative_normalization = hist_integral(bincenter, binwidth, inclusive_eec[ieta][ipt], rl_norm_lo, rl_norm_hi) / hist_integral(bincenter, binwidth, D0inpair_eec[ieta][ipt], rl_norm_lo, rl_norm_hi)\n    this_eta.append(D0inpair_eec[ieta][ipt] * relative_normalization)\n    this_eta_err.append(D0inpair_eec_err[ieta][ipt] * relative_normalization)\n  D0inpair_eec_relnorm.append(this_eta)\n  D0inpair_eec_relnorm_err.append(this_eta_err)\n\n  plt.rcParams["figure.figsize"] = [8, 6]\n  plt.title("D0 in pair, relative-normalized to inclusive, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")\n  plt.xlabel("R_L")\n  plt.ylabel("relative-normalized EEC")\n  plt.xscale(\'log\')\n  plt.yscale(\'log\')\n  plt.xlim(1E-2, 1)\n  plt.ylim(1E-4, 3E-1)\n  for ipt in range(len(pt_lo)):\n    plt.step(bincenter, inclusive_eec[ieta][ipt], where=\'mid\', color=colors[ipt], label="inclusive " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))\n    plt.errorbar(bincenter, inclusive_eec[ieta][ipt], yerr=inclusive_eec_err[ieta][ipt], capsize=2, fmt=\'.\', color=colors[ipt])\n  for ipt in range(len(pt_lo)):\n    plt.step(bincenter, D0inpair_eec_relnorm[ieta][ipt], where=\'mid\', color=light_colors[ipt], label="charm jet " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))\n    plt.errorbar(bincenter, D0inpair_eec_relnorm[ieta][ipt], yerr=D0inpair_eec_relnorm_err[ieta][ipt], capsize=2, fmt=\'.\', color=light_colors[ipt])\n  plt.legend(loc=\'upper left\')\n  plt.show()\n  '

# %%
etabin_pick = 1
ptbin_pick = 2

print(inclusive_eec[etabin_pick][ptbin_pick])

plt.rcParams["figure.figsize"] = [8, 6]
plt.xlabel("R_L")
plt.ylabel("relative-normalized EEC")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1E-3, 1)
#plt.ylim(1E-4, 3E-1)
plt.step(bincenter, inclusive_eec[etabin_pick][ptbin_pick], where='mid', color=light_colors[0], label="inclusive")
plt.errorbar(bincenter, inclusive_eec[etabin_pick][ptbin_pick], yerr=inclusive_eec_err[etabin_pick][ptbin_pick], capsize=2, fmt='.', color=light_colors[0])
plt.step(bincenter, D0injet_eec[etabin_pick][ptbin_pick], where='mid', color=light_colors[1], label="in jet")
plt.errorbar(bincenter, D0injet_eec[etabin_pick][ptbin_pick], yerr=D0injet_eec_err[etabin_pick][ptbin_pick], capsize=2, fmt='.', color=light_colors[1])
#plt.step(bincenter, D0inpair_eec[etabin_pick][ptbin_pick], where='mid', color=light_colors[2], label="in pair")
#plt.errorbar(bincenter, D0inpair_eec[etabin_pick][ptbin_pick], yerr=D0inpair_eec_err[etabin_pick][ptbin_pick], capsize=2, fmt='.', color=light_colors[2])
plt.legend(loc='upper left')
plt.show()

plt.rcParams["figure.figsize"] = [8, 6]
plt.xlabel("R_L")
plt.ylabel("relative-normalized EEC")
plt.xscale('log')
plt.yscale('log')
plt.xlim(1E-3, 1)
#plt.ylim(1E-4, 3E-1)
plt.step(bincenter, inclusive_eec[etabin_pick][ptbin_pick], where='mid', color=light_colors[0], label="inclusive")
plt.errorbar(bincenter, inclusive_eec[etabin_pick][ptbin_pick], yerr=inclusive_eec_err[etabin_pick][ptbin_pick], capsize=2, fmt='.', color=light_colors[0])
plt.step(bincenter, D0injet_eec_relnorm[etabin_pick][ptbin_pick], where='mid', color=light_colors[1], label="in jet")
plt.errorbar(bincenter, D0injet_eec_relnorm[etabin_pick][ptbin_pick], yerr=D0injet_eec_relnorm_err[etabin_pick][ptbin_pick], capsize=2, fmt='.', color=light_colors[1])
#plt.step(bincenter, D0inpair_eec_relnorm[etabin_pick][ptbin_pick], where='mid', color=light_colors[2], label="in pair")
#plt.errorbar(bincenter, D0inpair_eec_relnorm[etabin_pick][ptbin_pick], yerr=D0inpair_eec_relnorm_err[etabin_pick][ptbin_pick], capsize=2, fmt='.', color=light_colors[2])
plt.legend(loc='upper left')
plt.show()
# Out:
# [0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00
#  0.00000e+00 0.00000e+00 8.87749e-06 2.18769e-05 5.03379e-05 0.00000e+00
#  0.00000e+00 3.64493e-06 0.00000e+00 5.22768e-06 8.00305e-05 6.24200e-06
#  4.94038e-05 1.85949e-04 1.49518e-04 4.38307e-04 2.92339e-04 7.57761e-04
#  9.19544e-04 7.80327e-04 1.33073e-03 2.34399e-03 3.23118e-03 4.80180e-03
#  8.59829e-03 1.05543e-02 1.43642e-02 2.07512e-02 2.71004e-02 3.73662e-02
#  4.74864e-02 5.88247e-02 6.97901e-02 7.55339e-02 7.94800e-02 7.96400e-02
#  7.74990e-02 7.10487e-02 6.67305e-02 5.93403e-02 5.42905e-02 4.96845e-02
#  4.16468e-02 3.48130e-02]

# %%
# [charm jet / inclusive] EEC ratio, charm relatively normalized

def ratio_err(a, b, a_err, b_err):
  return np.sqrt((a_err / b)**2 + (a * b_err / (b**2))**2)

# D0 in jet
D0injet_eec_ratio = [None]
D0injet_eec_ratio_err = [None]
for ieta in range(1,len(eta_lo)):
  this_eta = []
  this_eta_err = []
  for ipt in range(len(pt_lo)):
    this_eta.append(D0injet_eec_relnorm[ieta][ipt] / inclusive_eec[ieta][ipt])
    this_eta_err.append(ratio_err(D0injet_eec_relnorm[ieta][ipt], inclusive_eec[ieta][ipt], D0injet_eec_relnorm_err[ieta][ipt], inclusive_eec_err[ieta][ipt]))
  D0injet_eec_ratio.append(this_eta)
  D0injet_eec_ratio_err.append(this_eta_err)

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("D0 in jet ratio over inclusive, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("charm / inclusive EEC")
  plt.xscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(0, 2)
  for ipt in range(len(pt_lo)-1):
    plt.step(bincenter, D0injet_eec_ratio[ieta][ipt], where='mid', color=colors[ipt], label="charm jet " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, D0injet_eec_ratio[ieta][ipt], yerr=D0injet_eec_ratio_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
  plt.plot(bincenter, [1 for i in range(len(bincenter))], '--', color='black')
  plt.legend(loc='upper left')
  plt.show()

# D0 in pair
"""
D0inpair_eec_ratio = [None]
D0inpair_eec_ratio_err = [None]
for ieta in range(1,len(eta_lo)):
  this_eta = []
  this_eta_err = []
  for ipt in range(len(pt_lo)):
    this_eta.append(D0inpair_eec_relnorm[ieta][ipt] / inclusive_eec[ieta][ipt])
    this_eta_err.append(ratio_err(D0inpair_eec_relnorm[ieta][ipt], inclusive_eec[ieta][ipt], D0inpair_eec_relnorm_err[ieta][ipt], inclusive_eec_err[ieta][ipt]))
  D0inpair_eec_ratio.append(this_eta)
  D0inpair_eec_ratio_err.append(this_eta_err)

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("D0 in pair ratio over inclusive, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("charm / inclusive EEC")
  plt.xscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(0, 2)
  for ipt in range(len(pt_lo)):
    plt.step(bincenter, D0inpair_eec_ratio[ieta][ipt], where='mid', color=colors[ipt], label="charm jet " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, D0inpair_eec_ratio[ieta][ipt], yerr=D0inpair_eec_ratio_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
  plt.plot(bincenter, [1 for i in range(len(bincenter))], '--', color='black')
  plt.legend(loc='upper left')
  plt.show()
  """
# Out:
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_15420\4060832228.py:13: RuntimeWarning: invalid value encountered in true_divide
#   this_eta.append(D0injet_eec_relnorm[ieta][ipt] / inclusive_eec[ieta][ipt])
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_15420\4060832228.py:4: RuntimeWarning: invalid value encountered in true_divide
#   return np.sqrt((a_err / b)**2 + (a * b_err / (b**2))**2)
# '\nD0inpair_eec_ratio = [None]\nD0inpair_eec_ratio_err = [None]\nfor ieta in range(1,len(eta_lo)):\n  this_eta = []\n  this_eta_err = []\n  for ipt in range(len(pt_lo)):\n    this_eta.append(D0inpair_eec_relnorm[ieta][ipt] / inclusive_eec[ieta][ipt])\n    this_eta_err.append(ratio_err(D0inpair_eec_relnorm[ieta][ipt], inclusive_eec[ieta][ipt], D0inpair_eec_relnorm_err[ieta][ipt], inclusive_eec_err[ieta][ipt]))\n  D0inpair_eec_ratio.append(this_eta)\n  D0inpair_eec_ratio_err.append(this_eta_err)\n\n  plt.rcParams["figure.figsize"] = [8, 6]\n  plt.title("D0 in pair ratio over inclusive, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")\n  plt.xlabel("R_L")\n  plt.ylabel("charm / inclusive EEC")\n  plt.xscale(\'log\')\n  plt.xlim(1E-2, 1)\n  plt.ylim(0, 2)\n  for ipt in range(len(pt_lo)):\n    plt.step(bincenter, D0inpair_eec_ratio[ieta][ipt], where=\'mid\', color=colors[ipt], label="charm jet " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))\n    plt.errorbar(bincenter, D0inpair_eec_ratio[ieta][ipt], yerr=D0inpair_eec_ratio_err[ieta][ipt], capsize=2, fmt=\'.\', color=colors[ipt])\n  plt.plot(bincenter, [1 for i in range(len(bincenter))], \'--\', color=\'black\')\n  plt.legend(loc=\'upper left\')\n  plt.show()\n  '

# %%
# jet multiplicity of inclusive and charged particles
# charged particles for the charm jets includes whatever particle is fixed, i.e. D0

""" doesn't totally work but maybe useful
def read_2D_csv_data(data, dim1, dim2):
    bincenter = data[0]
    binwidth = data[1]
    data = data[2:]
    data_err_split = data.reshape(2, dim2)
    central = data_err_split[0]
    err = data_err_split[1]
    central = central.reshape(dim1, dim2)
    err = err.reshape(dim1, dim2)
    return bincenter, binwidth, central, err
"""
# Out:
# " doesn't totally work but maybe useful\ndef read_2D_csv_data(data, dim1, dim2):\n    bincenter = data[0]\n    binwidth = data[1]\n    data = data[2:]\n    data_err_split = data.reshape(2, dim2)\n    central = data_err_split[0]\n    err = data_err_split[1]\n    central = central.reshape(dim1, dim2)\n    err = err.reshape(dim1, dim2)\n    return bincenter, binwidth, central, err\n"

# %%
# "bump plots", comparing charm jet and inclusive, D0 tagged relatively normalized to inclusive at HIGH RL

highrl_norm_lo = 0.6
highrl_norm_hi = 1

inclusive_bump = inclusive_eec / binwidth
inclusive_bump_err = inclusive_eec_err / binwidth
D0injet_bump = D0injet_eec / binwidth
D0injet_bump_err = D0injet_eec_err / binwidth

for ieta in range(1,3):
    for ipt in range(1,3):

        plt.rcParams["figure.figsize"] = [8, 6]
        plt.title("bump plot, EEC / binwidth, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"], pT=["+str(pt_lo[ipt])+","+str(pt_hi[ipt])+"]")
        plt.xlabel("R_L")
        plt.ylabel("EEC / binwidth")
        plt.xscale('log')
        plt.xlim(1E-2, 1)
        #plt.ylim(0, 2)

        # normalize by area
        const_binwidth = [1 for i in range(len(binwidth))]

        inc_int = hist_integral(bincenter, const_binwidth, inclusive_bump[ieta][ipt], a=highrl_norm_lo, b=highrl_norm_hi)
        print(inc_int)

        D0injet_int = hist_integral(bincenter, const_binwidth, D0injet_bump[ieta][ipt], a=highrl_norm_lo, b=highrl_norm_hi)
        print(D0injet_int)
        D0injet_norm = D0injet_bump[ieta][ipt] * (inc_int / D0injet_int)
        D0injet_norm_err = D0injet_bump_err[ieta][ipt] * (inc_int / D0injet_int)

        plt.step(bincenter, inclusive_bump[ieta][ipt], where='mid', color=colors[0], label="inclusive")
        plt.errorbar(bincenter, inclusive_bump[ieta][ipt], yerr=inclusive_bump_err[ieta][ipt], capsize=2, fmt='.', color=colors[0])
        plt.step(bincenter, D0injet_norm, where='mid', color=colors[1], label="D0 in jet")
        plt.errorbar(bincenter, D0injet_norm, yerr=D0injet_norm_err, capsize=2, fmt='.', color=colors[1])
        
        plt.legend(loc='upper left')
        plt.show()
# Out:
# 1.4067259740355866
# 1.839414578225483
# 0.9314249157920578
# 1.2166250654010617
# 1.4165131913720288
# 2.1098524527003715
# 0.9505027734631704
# 1.7075351554227463

# %%
# "bump plots", comparing charm jet and inclusive, abosolute normalized by number of jets in pt,eta bin

inclusive_eec_normbyjets = []
inclusive_eec_normbyjets_err = []
for ieta in range(len(eta_lo)):
  data = np.loadtxt(pythia8_inclusive + "eec_overlay_normbyjets_"+str(ieta)+".csv", delimiter=",", dtype=float)
  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)
  inclusive_eec_normbyjets.append([pt0, pt1, pt2])
  inclusive_eec_normbyjets_err.append([pt0_err, pt1_err, pt2_err])

D0injet_eec_normbyjets = []
D0injet_eec_normbyjets_err = []
for ieta in range(len(eta_lo)):
  data = np.loadtxt(pythia8_D0injet + "eec_overlay_normbyjets_"+str(ieta)+".csv", delimiter=",", dtype=float)
  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)
  D0injet_eec_normbyjets.append([pt0, pt1, pt2])
  D0injet_eec_normbyjets_err.append([pt0_err, pt1_err, pt2_err])
bin_lo = np.array(bincenter) - 0.5*np.array(binwidth)
bin_hi = np.array(bincenter) + 0.5*np.array(binwidth)

for ieta in range(1,3):
    for ipt in range(1,3):

      plt.rcParams["figure.figsize"] = [8, 6]
      plt.title("bump plot, EEC / binwidth, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"], pT=["+str(pt_lo[ipt])+","+str(pt_hi[ipt])+"]")
      plt.xlabel("R_L")
      plt.ylabel("EEC / binwidth")
      plt.xscale('log')
      plt.xlim(1E-2, 1)

      inc_normbyjets = inclusive_eec_normbyjets[ieta][ipt] / binwidth
      inc_normbyjets_err = inclusive_eec_normbyjets_err[ieta][ipt] / binwidth
      D0_normbyjets = D0injet_eec_normbyjets[ieta][ipt] / binwidth
      D0_normbyjets_err = D0injet_eec_normbyjets_err[ieta][ipt] / binwidth

      plt.step(bincenter, inc_normbyjets, where='mid', color=colors[0], label="inclusive")
      plt.errorbar(bincenter, inc_normbyjets, yerr=inc_normbyjets_err, capsize=2, fmt='.', color=colors[0])
      plt.step(bincenter, D0_normbyjets, where='mid', color=colors[1], label="D0 in jet")
      plt.errorbar(bincenter, D0_normbyjets, yerr=D0_normbyjets_err, capsize=2, fmt='.', color=colors[1])

      plt.legend(loc='upper left')
      plt.show()

# %%
# pow=0.5, pow=1 comparison

"""
# load in the pow=0.5
pythia8_inclusive_pow05 = "./analysis/ep_10_100_pythia8_pow05_inclusive/"
pythia8_D0injet_pow05 = "./analysis/ep_10_100_pythia8_pow05_D0injet/"

# inclusive in jet

inclusive_eec_pow05 = []
inclusive_eec_pow05_err = []
for ieta in range(len(eta_lo)):
  data = np.loadtxt(pythia8_inclusive_pow05 + "eec_overlay_"+str(ieta)+".csv", delimiter=",", dtype=float)
  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)
  inclusive_eec_pow05.append([pt0, pt1, pt2])
  inclusive_eec_pow05_err.append([pt0_err, pt1_err, pt2_err])
  bin_lo = np.array(bincenter) - 0.5*np.array(binwidth)
  bin_hi = np.array(bincenter) + 0.5*np.array(binwidth)

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("inclusive EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("self-normalized EEC")
  plt.xscale('log')
  plt.yscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(1E-4, 3E-1)
  for ipt in range(len(pt_lo)-1):
    plt.step(bincenter, inclusive_eec[ieta][ipt], where='mid', color=colors[ipt], label="pow=1, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, inclusive_eec[ieta][ipt], yerr=inclusive_eec_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
    plt.step(bincenter, inclusive_eec_pow05[ieta][ipt], where='mid', color=light_colors[ipt], label="pow=0.5, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, inclusive_eec_pow05[ieta][ipt], yerr=inclusive_eec_pow05_err[ieta][ipt], capsize=2, fmt='.', color=light_colors[ipt])
  plt.legend(loc='upper left')
  plt.show()

# D0 in jet
D0injet_eec_pow05 = []
D0injet_eec_pow05_err = []
for ieta in range(len(eta_lo)):
  data = np.loadtxt(pythia8_D0injet_pow05 + "eec_overlay_"+str(ieta)+".csv", delimiter=",", dtype=float)
  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)
  D0injet_eec_pow05.append([pt0, pt1, pt2])
  D0injet_eec_pow05_err.append([pt0_err, pt1_err, pt2_err])

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("D0 in jet, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("self-normalized EEC")
  plt.xscale('log')
  plt.yscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(1E-4, 3E-1)
  for ipt in range(len(pt_lo)-1):
    plt.step(bincenter, D0injet_eec[ieta][ipt], where='mid', color=colors[ipt], label="pow=1, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, D0injet_eec[ieta][ipt], yerr=D0injet_eec_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
    plt.step(bincenter, D0injet_eec_pow05[ieta][ipt], where='mid', color=light_colors[ipt], label="pow=0.5, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, D0injet_eec_pow05[ieta][ipt], yerr=D0injet_eec_pow05_err[ieta][ipt], capsize=2, fmt='.', color=light_colors[ipt])
  plt.legend(loc='upper left')
  plt.show()
"""
# Out:
# '\n# load in the pow=0.5\npythia8_inclusive_pow05 = "./analysis/ep_10_100_pythia8_pow05_inclusive/"\npythia8_D0injet_pow05 = "./analysis/ep_10_100_pythia8_pow05_D0injet/"\n\n# inclusive in jet\n\ninclusive_eec_pow05 = []\ninclusive_eec_pow05_err = []\nfor ieta in range(len(eta_lo)):\n  data = np.loadtxt(pythia8_inclusive_pow05 + "eec_overlay_"+str(ieta)+".csv", delimiter=",", dtype=float)\n  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)\n  inclusive_eec_pow05.append([pt0, pt1, pt2])\n  inclusive_eec_pow05_err.append([pt0_err, pt1_err, pt2_err])\n  bin_lo = np.array(bincenter) - 0.5*np.array(binwidth)\n  bin_hi = np.array(bincenter) + 0.5*np.array(binwidth)\n\n  plt.rcParams["figure.figsize"] = [8, 6]\n  plt.title("inclusive EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")\n  plt.xlabel("R_L")\n  plt.ylabel("self-normalized EEC")\n  plt.xscale(\'log\')\n  plt.yscale(\'log\')\n  plt.xlim(1E-2, 1)\n  plt.ylim(1E-4, 3E-1)\n  for ipt in range(len(pt_lo)-1):\n    plt.step(bincenter, inclusive_eec[ieta][ipt], where=\'mid\', color=colors[ipt], label="pow=1, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))\n    plt.errorbar(bincenter, inclusive_eec[ieta][ipt], yerr=inclusive_eec_err[ieta][ipt], capsize=2, fmt=\'.\', color=colors[ipt])\n    plt.step(bincenter, inclusive_eec_pow05[ieta][ipt], where=\'mid\', color=light_colors[ipt], label="pow=0.5, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))\n    plt.errorbar(bincenter, inclusive_eec_pow05[ieta][ipt], yerr=inclusive_eec_pow05_err[ieta][ipt], capsize=2, fmt=\'.\', color=light_colors[ipt])\n  plt.legend(loc=\'upper left\')\n  plt.show()\n\n# D0 in jet\nD0injet_eec_pow05 = []\nD0injet_eec_pow05_err = []\nfor ieta in range(len(eta_lo)):\n  data = np.loadtxt(pythia8_D0injet_pow05 + "eec_overlay_"+str(ieta)+".csv", delimiter=",", dtype=float)\n  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)\n  D0injet_eec_pow05.append([pt0, pt1, pt2])\n  D0injet_eec_pow05_err.append([pt0_err, pt1_err, pt2_err])\n\n  plt.rcParams["figure.figsize"] = [8, 6]\n  plt.title("D0 in jet, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")\n  plt.xlabel("R_L")\n  plt.ylabel("self-normalized EEC")\n  plt.xscale(\'log\')\n  plt.yscale(\'log\')\n  plt.xlim(1E-2, 1)\n  plt.ylim(1E-4, 3E-1)\n  for ipt in range(len(pt_lo)-1):\n    plt.step(bincenter, D0injet_eec[ieta][ipt], where=\'mid\', color=colors[ipt], label="pow=1, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))\n    plt.errorbar(bincenter, D0injet_eec[ieta][ipt], yerr=D0injet_eec_err[ieta][ipt], capsize=2, fmt=\'.\', color=colors[ipt])\n    plt.step(bincenter, D0injet_eec_pow05[ieta][ipt], where=\'mid\', color=light_colors[ipt], label="pow=0.5, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))\n    plt.errorbar(bincenter, D0injet_eec_pow05[ieta][ipt], yerr=D0injet_eec_pow05_err[ieta][ipt], capsize=2, fmt=\'.\', color=light_colors[ipt])\n  plt.legend(loc=\'upper left\')\n  plt.show()\n'

# %%
# (with decay and 18x275) vs (without decay and 18x275)

wo_pythia8_inclusive = "./analysis/ep_18_275_pow1_inclusive/"
wo_pythia8_D0injet = "./analysis/ep_18_275_pow1_D0injet/"

wo_inclusive_eec = []
wo_inclusive_eec_err = []
for ieta in range(len(eta_lo)):
  data = np.loadtxt(wo_pythia8_inclusive + "eec_overlay_"+str(ieta)+".csv", delimiter=",", dtype=float)
  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)
  wo_inclusive_eec.append([pt0, pt1, pt2])
  wo_inclusive_eec_err.append([pt0_err, pt1_err, pt2_err])
  bin_lo = np.array(bincenter) - 0.5*np.array(binwidth)
  bin_hi = np.array(bincenter) + 0.5*np.array(binwidth)

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("inclusive EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("self-normalized EEC")
  plt.xscale('log')
  plt.yscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(1E-4, 3E-1)
  for ipt in range(len(pt_lo)-1):
    plt.step(bincenter, wo_inclusive_eec[ieta][ipt], where='mid', color=colors[ipt], label="decay on, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, wo_inclusive_eec[ieta][ipt], yerr=wo_inclusive_eec_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
  for ipt in range(len(pt_lo)-1):
    plt.step(bincenter, inclusive_eec[ieta][ipt], where='mid', color=light_colors[ipt], label="decay off, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, inclusive_eec[ieta][ipt], yerr=inclusive_eec_err[ieta][ipt], capsize=2, fmt='.', color=light_colors[ipt])
  plt.legend(loc='upper left')
  plt.show()

# D0 in jet
wo_D0injet_eec = []
wo_D0injet_eec_err = []
for ieta in range(len(eta_lo)):
  data = np.loadtxt(wo_pythia8_D0injet + "eec_overlay_"+str(ieta)+".csv", delimiter=",", dtype=float)
  [bincenter, binwidth, pt0, pt0_err, pt1, pt1_err, pt2, pt2_err] = np.transpose(data)
  wo_D0injet_eec.append([pt0, pt1, pt2])
  wo_D0injet_eec_err.append([pt0_err, pt1_err, pt2_err])

  plt.rcParams["figure.figsize"] = [8, 6]
  plt.title("D0 in jet, EEC, eta=["+str(eta_lo[ieta])+","+str(eta_hi[ieta])+"]")
  plt.xlabel("R_L")
  plt.ylabel("self-normalized EEC")
  plt.xscale('log')
  plt.yscale('log')
  plt.xlim(1E-2, 1)
  plt.ylim(1E-4, 3E-1)
  for ipt in range(len(pt_lo)-1):
    plt.step(bincenter, wo_D0injet_eec[ieta][ipt], where='mid', color=colors[ipt], label="decay on, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, wo_D0injet_eec[ieta][ipt], yerr=wo_D0injet_eec_err[ieta][ipt], capsize=2, fmt='.', color=colors[ipt])
  for ipt in range(len(pt_lo)-1):
    plt.step(bincenter, D0injet_eec[ieta][ipt], where='mid', color=light_colors[ipt], label="decay off, " + str(pt_lo[ipt]) + " < pT < " + str(pt_hi[ipt]))
    plt.errorbar(bincenter, D0injet_eec[ieta][ipt], yerr=D0injet_eec_err[ieta][ipt], capsize=2, fmt='.', color=light_colors[ipt])
  plt.legend(loc='upper left')
  plt.show()
